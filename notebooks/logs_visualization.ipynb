# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
from scipy import stats
import tensorboard as tb

# %%
experiment_id = " C_DQN_0.9_128_16-33-43_23-01-2021 "
experiment = tb.data.experimental.ExperimentFromDev(experiment_id)
df = experiment.get_scalars()
# Out:
# ---------------------------------------------------------------------------
# _MultiThreadedRendezvous                  Traceback (most recent call last)
# <ipython-input-2-d1b054e106e5> in <module>
#       1 experiment_id = " C_DQN_0.9_128_16-33-43_23-01-2021 "
#       2 experiment = tb.data.experimental.ExperimentFromDev(experiment_id)
# ----> 3 df = experiment.get_scalars()
#       4
#
# ~/miniconda3/envs/probable-giggle-new/lib/python3.8/site-packages/tensorboard/data/experimental/experiment_from_dev.py in get_scalars(self, runs_filter, tags_filter, pivot, include_wall_time)
#     103         wall_times = []
#     104         values = []
# --> 105         for response in stream:
#     106             # TODO(cais, wchargin): Display progress bar during data loading.
#     107             num_values = len(response.points.values)
#
# ~/miniconda3/envs/probable-giggle-new/lib/python3.8/site-packages/grpc/_channel.py in __next__(self)
#     414
#     415     def __next__(self):
# ...

# %%
low_gamma = pd.read_csv("temp_logs/run-C_DQN_0.8_128_15-13-02_23-01-2021-tag-Episode reward.csv")
medium_gamma = pd.read_csv("temp_logs/run-C_DQN_0.9_128_16-33-43_23-01-2021-tag-Episode reward.csv")
high_gamma = pd.read_csv("temp_logs/run-C_DQN_0.95_128_17-37-52_23-01-2021-tag-Episode reward.csv")

# %%
sns.lineplot(data=low_gamma, x='Step', y='Value')
# Out:
# <AxesSubplot:xlabel='Step', ylabel='Value'>

# %%
low_gamma
# Out:
#         Wall time  Step      Value
# 0    1.611415e+09     5   4.042857
# 1    1.611415e+09     6   2.068571
# 2    1.611415e+09    10   2.114286
# 3    1.611415e+09    11   2.125714
# 4    1.611415e+09    13   4.111429
# ..            ...   ...        ...
# 995  1.611419e+09  1982 -10.000000
# 996  1.611419e+09  1983  10.000000
# 997  1.611419e+09  1995  10.000000
# 998  1.611419e+09  1997 -10.000000
# 999  1.611419e+09  1999  10.000000
#
# [1000 rows x 3 columns]
